# %% [markdown]
# ## Matplotlib and Visualization
#
# ## On-Class Workshop

# %% [markdown]
# #### 1. Import the matplotlib.pyplot library and run this cell.

# %%
import matplotlib.pyplot as plt
# Create graphics
plt.figure()
plt.plot([1, 2, 3, 4], [10, 20, 25, 30])
plt.title('No styles', )
plt.xlabel('x Axis')
plt.ylabel('Y Axis')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2. Add some styles and features. Put in something in the place of "Write Here".

# %%
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='purple', linestyle='--', linewidth='2', markerfacecolor='red', marker='o', markersize='8')

# %%
plt.title('No styles', )
plt.xlabel('x Axis')
plt.ylabel('Y Axis')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# Create graphics
plt.figure()
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='Write Here', linestyle='Write Here', linewidth='Write Here', markerfacecolor='Write Here', marker='o', markersize='8')
plt.title('Custom styles', fontsize='Write Here', fontweight='bold', color='Write Here')
plt.xlabel('x Axis',fontsize='Write Here',fontname='Write Here' )
plt.ylabel('Y Axis',fontsize='Write Here',fontname='Write Here' )
plt.grid(True)
plt.show()

# %% [markdown]
# #### 3. Show the first 6 rows of the dataframe

# %%
df.head(6)

# %% [markdown]
# #### 4. Show the last 3 rows of the dataframe

# %%
df.tail(3)

# %% [markdown]
# #### 5. Show the size of the dataframe (no. of rows and columns)

# %%
df_shape = df.shape
df_shape
# Out:
# (96453, 12)

# %% [markdown]
# #### 7. Check if any missing values in the dataframe

# %%
has_missing_values = df.isnull().values.any()
has_missing_values
# Out:
# True

# %% [markdown]
# #### 8. Check if any missing values in each column

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64
